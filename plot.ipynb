# %%
x = [0, 0.2, 0.4, 0.6, 0.8, 1]
auc_mdnf = [0.821, 0.826, 0.8252, 0.8255, 0.825, 0.8238]
gini_mdnf = [0.736, 0.7484, 0.741, 0.7459, 0.7418, 0.7466]
auc_dhp = [0.8715, 0.8724, 0.872, 0.872, 0.8728, 0.8721]
gini_dhp = [0.7256, 0.738, 0.7283, 0.7272, 0.7319, 0.7384]
auc_wxsh = [0.8557, 0.8639, 0.8604, 0.8581, 0.8606, 0.8582]
gini_wxsh = [0.8172, 0.8369, 0.8341, 0.8242, 0.8301, 0.8228]
auc_wm = [0.6884, 0.6963, 0.6939, 0.6761, 0.674, 0.6916]
gini_wm = [0.558, 0.5716, 0.6049, 0.5641, 0.5824, 0.5593]

# %%
x = [0, 0.2, 0.4, 0.6, 0.8, 1]
auc_mdnf = [0.821, 0.826, 0.8252, 0.8255, 0.825, 0.8238]
gini_mdnf = [0.736, 0.7484, 0.741, 0.7459, 0.7418, 0.7466]
auc_dhp = [0.8715, 0.8724, 0.872, 0.872, 0.8728, 0.8721]
gini_dhp = [0.7256, 0.738, 0.7283, 0.7272, 0.7319, 0.7384]
auc_wxsh = [0.8557, 0.8639, 0.8604, 0.8581, 0.8606, 0.8582]
gini_wxsh = [0.8172, 0.8369, 0.8341, 0.8242, 0.8301, 0.8228]
auc_wm = [0.6884, 0.6963, 0.6939, 0.6761, 0.674, 0.6916]
gini_wm = [0.558, 0.5716, 0.6049, 0.5641, 0.5824, 0.5593]


import matplotlib.pyplot as plt

# # 创建一个新的图形
# plt.figure(dpi=600)

# # 绘制第一条折线
# plt.plot(x, auc_mdnf, label='mdnf', marker='^', linestyle='-')
# plt.plot(x, auc_dhp, label='dhp', marker='^', linestyle='--')
# plt.plot(x, auc_wxsh, label='wxsh',marker='^', linestyle='--')
# plt.plot(x, auc_wm, label='wm', marker='^', linestyle='--')

# # 添加标题和轴标签
# plt.xlabel('TLabel loss weight for TRGT')
# plt.ylabel('AUC')

# # 添加图例
# plt.legend()

# # 显示图形
# plt.show()

# 创建一个新的图形
plt.figure(dpi=600)

# 绘制第一条折线
plt.plot(x, gini_mdnf, label='Game A', marker='^', linestyle='--')
plt.plot(x, gini_dhp, label='Game B', marker='^', linestyle='--')
plt.plot(x, gini_wxsh, label='Game C', marker='^', linestyle='--')
plt.plot(x, gini_wm, label='Game D', marker='^', linestyle='--')

# # 添加标题和轴标签
# plt.xlabel('TLabel loss weight for TRGT')
# plt.ylabel('GINI')

# 添加图例
plt.legend(loc='center right', bbox_to_anchor=(1, 0.35), fontsize=16)

plt.xlabel(r'TLabel loss weight $\alpha$ of TRGT', fontsize=16)
plt.ylabel(r'GINI', fontsize=16)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

# 显示图形
plt.savefig('tl_gini.png')

# %%
x = [0, 0.2, 0.4, 0.6, 0.8, 1]
auc_mdnf = [0.8268, 0.8292, 0.8283, 0.82827, 0.8284, 0.8285]
gini_mdnf = [0.7413, 0.753, 0.7528, 0.7533, 0.7412, 0.74352]
auc_dhp = [0.8722, 0.8738, 0.8713, 0.8725, 0.8735, 0.8731]
gini_dhp = [0.7316, 0.7396, 0.738, 0.734, 0.7348, 0.7263]
auc_wxsh = [0.8531, 0.8614, 0.8586, 0.8552, 0.8583, 0.858]
gini_wxsh = [0.8264, 0.8381, 0.8315, 0.8389, 0.8399, 0.8408]
auc_wm = [0.6975, 0.708, 0.7038, 0.7053, 0.7055, 0.7077]
gini_wm = [0.5737, 0.601, 0.5838, 0.6029, 0.6107, 0.5828]


import matplotlib.pyplot as plt

# # 创建一个新的图形
# plt.figure(dpi=600)

# # 绘制第一条折线
# plt.plot(x, auc_mdnf, label='mdnf', marker='^', linestyle='-')
# plt.plot(x, auc_dhp, label='dhp', marker='^', linestyle='--')
# plt.plot(x, auc_wxsh, label='wxsh',marker='^', linestyle='--')
# plt.plot(x, auc_wm, label='wm', marker='^', linestyle='--')

# # 添加标题和轴标签
# plt.xlabel('TLabel loss weight for TRGT')
# plt.ylabel('AUC')

# # 添加图例
# plt.legend()

# # 显示图形
# plt.show()

# 创建一个新的图形
plt.figure(dpi=600)

# 绘制第一条折线
plt.plot(x, gini_mdnf, label='Game A', marker='^', linestyle='--')
plt.plot(x, gini_dhp, label='Game B', marker='^', linestyle='--')
plt.plot(x, gini_wxsh, label='Game C', marker='^', linestyle='--')
plt.plot(x, gini_wm, label='Game D', marker='^', linestyle='--')

# # 添加标题和轴标签
# plt.xlabel('TLabel loss weight for TRGT')
# plt.ylabel('GINI')

# 添加图例
plt.legend(loc='center right', bbox_to_anchor=(1, 0.365), fontsize=16)

plt.xlabel(r'Teacher loss weight $\beta$ of TPTL', fontsize=16)
plt.ylabel(r'GINI', fontsize=16)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

# 显示图形
plt.savefig('wt_gini.png')

# %%
# 创建一个新的图形
plt.figure()

# 绘制第一条折线
plt.plot(x, gini_mdnf, label='mdnf', marker='^', linestyle='-')
plt.plot(x, gini_dhp, label='dhp', marker='^', linestyle='--')
plt.plot(x, gini_wxsh, label='wxsh', marker='^', linestyle='--')
plt.plot(x, gini_wm, label='wm', marker='^', linestyle='--')

# 添加标题和轴标签
plt.title('多条折线示例')
plt.xlabel('x轴')
plt.ylabel('y轴')

# 添加图例
plt.legend()

# 显示图形
plt.show()
