# %%
import os
import numpy as np
import pandas as pd
from xgboost import XGBRegressor, XGBClassifier
from sklearn.ensemble import RandomForestRegressor
from utils.common import get_root_path, read_csv_list, evaluate
from sklearn.model_selection import train_test_split
from config.features import ACTIVE_FEATURES, ALL_FEATURES, get_feature_names

# %%
model = XGBRegressor()

# %%
jf_game_id = 'dhp'
train_csv_list = [os.path.join(get_root_path(), 'processed_data', f'{jf_game_id}/{jf_game_id}_6h_{date}.csv') for date in
                    range(801, 807 + 1)]
train_csv_list = [csv for csv in train_csv_list if os.path.exists(csv)]
train_df = read_csv_list(train_csv_list)
test_csv_list = [os.path.join(get_root_path(), 'processed_data', f'{jf_game_id}/{jf_game_id}_6h_{date}.csv') for date in
                    range(808, 808 + 1)]
test_csv_list = [csv for csv in test_csv_list if os.path.exists(csv)]
test_df = read_csv_list(test_csv_list)
# Out:
# 2024-10-07 20:14:58,947 - common.py - INFO - Read dataframe from csv D:/codes/www\processed_data\dhp/dhp_6h_801.csv | sample number: 557325
# D:\codes\www\utils\common.py:33: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   new_df = pd.read_csv(csv_file, usecols=columns, sep=sep)
# 2024-10-07 20:15:12,212 - common.py - INFO - Read dataframe from csv D:/codes/www\processed_data\dhp/dhp_6h_802.csv | sample number: 635971
# 2024-10-07 20:15:29,450 - common.py - INFO - Read dataframe from csv D:/codes/www\processed_data\dhp/dhp_6h_803.csv | sample number: 835078
# D:\codes\www\utils\common.py:33: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   new_df = pd.read_csv(csv_file, usecols=columns, sep=sep)
# 2024-10-07 20:15:46,038 - common.py - INFO - Read dataframe from csv D:/codes/www\processed_data\dhp/dhp_6h_804.csv | sample number: 789380
# D:\codes\www\utils\common.py:33: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   new_df = pd.read_csv(csv_file, usecols=columns, sep=sep)
# 2024-10-07 20:15:56,830 - common.py - INFO - Read dataframe from csv D:/codes/www\processed_data\dhp/dhp_6h_805.csv | sample number: 522957
# D:\codes\www\utils\common.py:33: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   new_df = pd.read_csv(csv_file, usecols=columns, sep=sep)
# 2024-10-07 20:16:09,065 - common.py - INFO - Read dataframe from csv D:/codes/www\processed_data\dhp/dhp_6h_806.csv | sample number: 553327
# 2024-10-07 20:16:20,033 - common.py - INFO - Read dataframe from csv D:/codes/www\processed_data\dhp/dhp_6h_807.csv | sample number: 522406
# 2024-10-07 20:16:40,516 - common.py - INFO - sample num: 4416444
# D:\codes\www\utils\common.py:33: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   new_df = pd.read_csv(csv_file, usecols=columns, sep=sep)
# 2024-10-07 20:16:48,348 - common.py - INFO - Read dataframe from csv D:/codes/www\processed_data\dhp/dhp_6h_808.csv | sample number: 546028
# 2024-10-07 20:16:48,349 - common.py - INFO - sample num: 546028

# %%
active_feature_names = get_feature_names(ACTIVE_FEATURES['sparse']) + ACTIVE_FEATURES['dense'] + ['o2_game_id_hash', 'media_type_hash', 'media_id_hash']  # + get_feature_names(ACTIVE_FEATURES['seq'])
all_feature_names = get_feature_names(ALL_FEATURES['sparse']) + ALL_FEATURES['dense'] + ['o2_game_id_hash', 'media_type_hash', 'media_id_hash']  # + get_feature_names(ALL_FEATURES['seq'])

# %%
def label_cast(x, label_max_cast):
    if x < 0:
        return 0
    elif x > label_max_cast:
        return label_max_cast
    else:
        return x

# %%
X_train = np.array(train_df[all_feature_names])
X_test =  np.array(test_df[all_feature_names])
y_train =  np.array((train_df['ltv3']-train_df['ltv_6h']).apply(lambda x: label_cast(x, label_max_cast=2000)))
y_test =  np.array((test_df['ltv3']-test_df['ltv_6h']).apply(lambda x: label_cast(x, label_max_cast=2000)))

# %%
X_train = np.array(train_df[active_feature_names])
X_test =  np.array(test_df[active_feature_names])
y_train =  np.array((train_df['ltv3']).apply(lambda x: label_cast(x, label_max_cast=2000)))
y_test =  np.array((test_df['ltv3']).apply(lambda x: label_cast(x, label_max_cast=2000)))

# %%
model.fit(np.array(X_train), np.array(y_train))
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = model.predict(np.array(X_test))

# %%
y_pred
# Out:
# array([0.01125324, 0.01125324, 0.04382861, ..., 0.01125324, 0.03921516,
#        0.10487259], dtype=float32)

# %%
predict_df = pd.DataFrame({'ltv3': np.array(y_test), 'pltv3':y_pred, 'is_pay': np.array(y_test)>0., 'pay_probs': y_pred})

# %%
eval_result = evaluate(predict_df)

# %%
predict_df
# Out:
#         ltv3     pltv3  is_pay  pay_probs
# 0        0.0  0.011253   False   0.011253
# 1        0.0  0.011253   False   0.011253
# 2        0.0  0.043829   False   0.043829
# 3        0.0  0.011253   False   0.011253
# 4        0.0  0.011253   False   0.011253
# ...      ...       ...     ...        ...
# 546023   0.0  0.072288   False   0.072288
# 546024   0.0  0.011253   False   0.011253
# 546025   0.0  0.011253   False   0.011253
# 546026   0.0  0.039215   False   0.039215
# 546027   0.0  0.104873   False   0.104873
#
# [546028 rows x 4 columns]

# %%
eval_result
# Out:
# {'auc': 0.8239939505664438,
#  'gini_by_pltv': 0.6853361886832359,
#  'gini_by_p': 0.6853361886832359,
#  'rmse': 12.136140727774805,
#  'nrmse': 0.006068070363887403,
#  'mae': 0.31773406774666263,
#  'nmae': 0.0001588670338733313,
#  'top_0.01_p_by_pltv': 0.1064102564102564,
#  'top_0.01_r_by_pltv': 0.25549692172383465,
#  'top_0.03_p_by_pltv': 0.053357753357753356,
#  'top_0.03_r_by_pltv': 0.3843447669305189,
#  'top_0.05_p_by_pltv': 0.03871653053001722,
#  'top_0.05_r_by_pltv': 0.4648197009674582,
#  'top_0.1_p_by_pltv': 0.02448628255375261,
#  'top_0.1_r_by_pltv': 0.5879507475813545,
#  'top_0.01_p_by_p': 0.1064102564102564,
#  'top_0.01_r_by_p': 0.25549692172383465,
#  'top_0.03_p_by_p': 0.053357753357753356,
#  'top_0.03_r_by_p': 0.3843447669305189,
#  'top_0.05_p_by_p': 0.03871653053001722,
#  'top_0.05_r_by_p': 0.4648197009674582,
#  'top_0.1_p_by_p': 0.02448628255375261,
#  'top_0.1_r_by_p': 0.5879507475813545,
#  'top_amount_recall_by_pltv': {},
#  'top_0.01_amount_recall_by_pltv': 57190.34,
#  'top_0.05_amount_recall_by_pltv': 74923.44,
#  'top_0.1_amount_recall_by_pltv': 80137.55,
#  'top_amount_recall_by_p': {},
#  'top_0.01_amount_recall_by_p': 57190.34,
#  'top_0.05_amount_recall_by_p': 74923.44,
#  'top_0.1_amount_recall_by_p': 80137.55}

# %%
# !pip install tune-sklearn ray[tune]
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting tune-sklearn
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/d9/48/05dd77618ccd92c5439f23bf472501378f081b163aea5ee60af51ec4c1d7/tune_sklearn-0.5.0-py3-none-any.whl (42 kB)
#      ---------------------------------------- 0.0/42.2 kB ? eta -:--:--
#      ---------------------------------------- 42.2/42.2 kB 1.0 MB/s eta 0:00:00
# Collecting ray[tune]
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/08/91/967506d22c3ef98cc6bcbd58bef04a3bfd8d15fe89979ac24de3a32b0a5f/ray-2.37.0-cp312-cp312-win_amd64.whl (24.9 MB)
#      ---------------------------------------- 0.0/24.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/24.9 MB 20.5 MB/s eta 0:00:02
#      - -------------------------------------- 0.7/24.9 MB 11.2 MB/s eta 0:00:03
#      - -------------------------------------- 1.1/24.9 MB 9.0 MB/s eta 0:00:03
#      --- ------------------------------------ 2.0/24.9 MB 11.4 MB/s eta 0:00:03
#      ---- ----------------------------------- 2.9/24.9 MB 13.2 MB/s eta 0:00:02
#      ------- -------------------------------- 4.5/24.9 MB 16.9 MB/s eta 0:00:02
#      --------- ------------------------------ 6.1/24.9 MB 19.4 MB/s eta 0:00:01
#      ------------- -------------------------- 8.4/24.9 MB 23.4 MB/s eta 0:00:01
#      ---------------- ---------------------- 10.6/24.9 MB 26.2 MB/s eta 0:00:01
#      -------------------- ------------------ 12.9/24.9 MB 38.6 MB/s eta 0:00:01
#      ----------------------- --------------- 15.2/24.9 MB 43.7 MB/s eta 0:00:01
#      -------------------------- ------------ 17.0/24.9 MB 43.7 MB/s eta 0:00:01
#      ------------------------------ -------- 19.2/24.9 MB 43.7 MB/s eta 0:00:01
#      --------------------------------- ----- 21.3/24.9 MB 46.7 MB/s eta 0:00:01
#      --------------------------------- ----- 21.3/24.9 MB 46.7 MB/s eta 0:00:01
#      --------------------------------- ----- 21.6/24.9 MB 36.3 MB/s eta 0:00:01
#      ------------------------------------ -- 23.3/24.9 MB 32.7 MB/s eta 0:00:01
#      ------------------------------------ -- 23.4/24.9 MB 29.7 MB/s eta 0:00:01
#      ------------------------------------- - 23.8/24.9 MB 25.1 MB/s eta 0:00:01
#      --------------------------------------  24.9/24.9 MB 24.3 MB/s eta 0:00:01
#      --------------------------------------- 24.9/24.9 MB 21.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in d:\app\miniconda3\lib\site-packages (from tune-sklearn) (1.5.0)
# Requirement already satisfied: scipy in d:\app\miniconda3\lib\site-packages (from tune-sklearn) (1.14.0)
# Requirement already satisfied: numpy>=1.16 in d:\app\miniconda3\lib\site-packages (from tune-sklearn) (1.26.4)
# Collecting click>=7.0 (from ray[tune])
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl (97 kB)
#      ---------------------------------------- 0.0/97.9 kB ? eta -:--:--
#      ---------------------------------------- 97.9/97.9 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in d:\app\miniconda3\lib\site-packages (from ray[tune]) (3.13.1)
# Requirement already satisfied: jsonschema in d:\app\miniconda3\lib\site-packages (from ray[tune]) (4.22.0)
# Collecting msgpack<2.0.0,>=1.0.0 (from ray[tune])
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/73/80/2708a4641f7d553a63bc934a3eb7214806b5b39d200133ca7f7afb0a53e8/msgpack-1.1.0-cp312-cp312-win_amd64.whl (75 kB)
#      ---------------------------------------- 0.0/75.3 kB ? eta -:--:--
#      ---------------------------------------- 75.3/75.3 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in d:\app\miniconda3\lib\site-packages (from ray[tune]) (23.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in d:\app\miniconda3\lib\site-packages (from ray[tune]) (4.25.3)
# Requirement already satisfied: pyyaml in d:\app\miniconda3\lib\site-packages (from ray[tune]) (6.0.1)
# Requirement already satisfied: aiosignal in d:\app\miniconda3\lib\site-packages (from ray[tune]) (1.3.1)
# Requirement already satisfied: frozenlist in d:\app\miniconda3\lib\site-packages (from ray[tune]) (1.4.1)
# Requirement already satisfied: requests in d:\app\miniconda3\lib\site-packages (from ray[tune]) (2.32.3)
# Requirement already satisfied: pandas in d:\app\miniconda3\lib\site-packages (from ray[tune]) (2.2.2)
# Collecting tensorboardX>=1.9 (from ray[tune])
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/44/71/f3e7c9b2ab67e28c572ab4e9d5fa3499e0d252650f96d8a3a03e26677f53/tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#      ---------------------------------------- 0.0/101.7 kB ? eta -:--:--
#      ---------------------------------------- 101.7/101.7 kB ? eta 0:00:00
# Requirement already satisfied: pyarrow>=6.0.1 in d:\app\miniconda3\lib\site-packages (from ray[tune]) (16.1.0)
# Requirement already satisfied: fsspec in d:\app\miniconda3\lib\site-packages (from ray[tune]) (2024.2.0)
# Requirement already satisfied: colorama in d:\app\miniconda3\lib\site-packages (from click>=7.0->ray[tune]) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in d:\app\miniconda3\lib\site-packages (from jsonschema->ray[tune]) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\app\miniconda3\lib\site-packages (from jsonschema->ray[tune]) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\app\miniconda3\lib\site-packages (from jsonschema->ray[tune]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\app\miniconda3\lib\site-packages (from jsonschema->ray[tune]) (0.18.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\app\miniconda3\lib\site-packages (from pandas->ray[tune]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\app\miniconda3\lib\site-packages (from pandas->ray[tune]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\app\miniconda3\lib\site-packages (from pandas->ray[tune]) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\app\miniconda3\lib\site-packages (from requests->ray[tune]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\app\miniconda3\lib\site-packages (from requests->ray[tune]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\app\miniconda3\lib\site-packages (from requests->ray[tune]) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\app\miniconda3\lib\site-packages (from requests->ray[tune]) (2024.6.2)
# Requirement already satisfied: joblib>=1.2.0 in d:\app\miniconda3\lib\site-packages (from scikit-learn->tune-sklearn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\app\miniconda3\lib\site-packages (from scikit-learn->tune-sklearn) (3.5.0)
# Requirement already satisfied: six>=1.5 in d:\app\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->ray[tune]) (1.16.0)
# Installing collected packages: tensorboardX, msgpack, click, ray, tune-sklearn
# Successfully installed click-8.1.7 msgpack-1.1.0 ray-2.37.0 tensorboardX-2.6.2.2 tune-sklearn-0.5.0
